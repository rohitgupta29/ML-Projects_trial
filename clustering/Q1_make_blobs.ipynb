# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std = 0.6)
X.shape, y_true.shape
# Out:
# ((300, 2), (300,))

# %%
# s= size of points
plt.scatter(X[:,0],X[:,1],s = 50)
plt.show()

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.scatter(X[:,0],X[:,1],s = 50, cmap = 'viridis', c = y_kmeans)
plt.show()

# %%
y_kmeans.shape
# Out:
# (300,)

# %%
X[:,0],X[:,1]
# Out:
# (array([-8.06962803e-01, -3.00255923e-01,  5.32325993e-04,  2.83942294e+00,
#          2.37804670e+00,  2.90922945e+00,  2.24437672e+00,  5.16613417e+00,
#          6.95128379e-01,  1.63328905e-01,  3.08001941e+00,  2.40144703e-01,
#          5.85319728e+00, -9.31809704e-01, -6.86271770e-01,  2.46392116e+00,
#         -1.48640962e-02,  3.00672637e+00,  6.90739070e+00, -9.56175337e-01,
#          6.44959732e+00, -1.54433930e+00,  5.91249409e+00,  1.93506730e+00,
#          2.78727559e-01,  6.71256298e+00, -1.01100063e+00,  2.72082262e+00,
#          2.94375410e+00, -1.61746441e+00,  2.77669498e+00, -1.57617731e-01,
#          6.51237001e-01,  6.08938725e+00, -3.17204640e-03,  6.68506228e+00,
#         -2.07640309e+00,  1.93800000e+00,  6.19396364e+00, -7.46608775e-02,
#         -3.21002019e-01, -3.31700877e-01,  5.18611124e+00,  2.62976033e+00,
#          2.14982417e+00, -1.22885745e-01, -7.40326305e-01, -5.24120733e-01,
# ...

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
# viridis color map
plt.scatter(X[:,0],X[:,1],s = 50, cmap = 'viridis', c = y_kmeans)
plt.show()

# %%
#Diverging colormaps, source = https://matplotlib.org/examples/color/colormaps_reference.html
plt.scatter(X[:,0],X[:,1],s = 50, cmap = 'PiYG', c = y_kmeans)
plt.show()

# %%
#Qualitative Colormaps
plt.scatter(X[:,0],X[:,1],s = 50, cmap = 'Set1', c = y_kmeans)
plt.show()

# %%
# cmap = miscellaneous Colormaps
plt.scatter(X[:,0],X[:,1],s = 50, cmap = 'prism', c = y_kmeans)
plt.show()

# %%
# sequential colormaps
plt.scatter(X[:,0],X[:,1],s = 50, cmap = 'spring', c = y_kmeans)
plt.show()
